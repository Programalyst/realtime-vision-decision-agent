# %%
import torch

print("PyTorch Version:", torch.__version__)

if torch.backends.mps.is_available():
    print("✅ Success! Found Apple Silicon GPU (MPS Mode Enabled)")
    device_target = "mps"
else:
    print("⚠️ MPS acceleration not found. Defaulting to CPU.")
    device_target = "cpu"
# Out:
# PyTorch Version: 2.8.0
# ✅ Success! Found Apple Silicon GPU (MPS Mode Enabled)

# %%
from roboflow import Roboflow
from ultralytics import YOLO

# 1. Replace this block with the code snippet from Roboflow
# Go to "Versions" > "Download Dataset" > select YOLOv11 > "Show download code"
rf = Roboflow(api_key="YOUR_ROBOFLOW_API_KEY_HERE")
project = rf.workspace("leonard-lin-yrqtn").project("collect-raindrops")
version = project.version(2)
dataset = version.download("yolov11")

# 2. Initialize the lightweight YOLOv11 nano framework
model = YOLO("yolo11n.pt") 

# 3. Kick off local training using Apple Silicon acceleration
results = model.train(
    data=f"{dataset.location}/data.yaml", 
    epochs=50,             
    imgsz=640,             
    device=device_target,
    val=False
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Collect-Raindrops-2 to yolov11:: 100%|█████████████████████████████████████████████████████████████| 796/796 [00:01<00:00, 708.59it/s]
# Extracting Dataset Version Zip to Collect-Raindrops-2 in yolov11:: 100%|███████████████████████████████████████████████████████████████| 76/76 [00:00<00:00, 3179.12it/s]
# New https://pypi.org/project/ultralytics/8.4.155 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.189 🚀 Python-3.13.5 torch-2.8.0 MPS (Apple M4 Pro)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/leonardlin/workspace/realtime-vision-decision-agent/Collect-Raindrops-2/data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=False, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 199.9±56.4 MB/s, size: 22.9 KB)
# train: Scanning /Users/leonardlin/workspace/realtime-vision-decision-agent/Collect-Raindrops-2/train/labels... 29 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 29/29 206.3it/s 0.1s
# train: New cache created: /Users/leonardlin/workspace/realtime-vision-decision-agent/Collect-Raindrops-2/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 222.8±42.2 MB/s, size: 21.7 KB)
# val: Scanning /Users/leonardlin/workspace/realtime-vision-decision-agent/Collect-Raindrops-2/valid/labels... 7 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7/7 5227.0it/s 0.0s
# val: New cache created: /Users/leonardlin/workspace/realtime-vision-decision-agent/Collect-Raindrops-2/valid/labels.cache
# Plotting labels to runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      4.26G      1.297      3.986      1.105         71        640: 100% ━━━━━━━━━━━━ 2/2 0.11it/s 18.3s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      4.27G      1.196      3.903      1.039         84        640: 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.7ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      4.24G      1.106      3.789      1.025         98        640: 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      4.27G       1.06      3.592      1.045         88        640: 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      5.25G       1.02       3.42     0.9781         96        640: 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.3ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      4.29G     0.9752      2.994     0.9697        100        640: 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      4.29G      0.981      2.791      0.966        108        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      4.27G     0.9507      2.541     0.9475        107        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      4.42G     0.8721      2.166     0.9118         99        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      4.27G     0.9123      1.984     0.9696        121        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      4.24G     0.8743      1.828     0.9295        125        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      4.24G     0.8263      1.581     0.9163         89        640: 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      4.27G     0.8315      1.474     0.9333         88        640: 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      4.24G     0.8319      1.448     0.9026        117        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      4.24G     0.8495      1.412     0.9003        127        640: 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      4.24G     0.7867      1.267     0.9293         98        640: 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      4.24G     0.7586      1.067      0.894        117        640: 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      4.24G     0.8386      1.285      0.906        119        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      4.24G     0.8113      1.101     0.9021        108        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      4.29G     0.7517     0.9931     0.8897         86        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      4.27G     0.8304      1.093     0.9343         79        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      5.24G     0.7516      1.039     0.9043         59        640: 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      4.28G     0.7876      1.004     0.8753        148        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      4.29G     0.8034     0.9846     0.8972        114        640: 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      5.26G     0.7828     0.9666     0.8871        117        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      5.25G     0.7639     0.8812     0.8864        106        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      4.32G     0.7336     0.8762      0.886        111        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50       5.3G     0.7599     0.8671     0.8579        124        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      4.45G     0.7083     0.7927      0.863         98        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      4.45G     0.7033     0.8755     0.9093         75        640: 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      4.42G     0.7297     0.8367     0.8706        108        640: 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      5.28G     0.7229      0.807     0.8552        156        640: 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50       4.3G     0.7291     0.8415     0.8679        152        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      4.33G     0.7618      0.834     0.8765        119        640: 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50       4.3G     0.6914     0.8094     0.8674        124        640: 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50       4.3G     0.7091     0.8075     0.8618        122        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50       4.3G     0.7229     0.7904     0.8653        117        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      4.27G     0.6951     0.7275     0.8579        108        640: 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      4.27G      0.721     0.7723     0.8836         84        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      4.24G     0.6571     0.7508      0.855        153        640: 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2ss
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      4.28G     0.7066     0.7907     0.8597         81        640: 100% ━━━━━━━━━━━━ 2/2 1.5it/s 1.3ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      4.25G     0.6649     0.7676     0.8651         75        640: 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      4.29G     0.6478     0.7327     0.8448         75        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      4.29G     0.6579     0.7436     0.8682         76        640: 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      4.29G     0.6295     0.7475     0.8689         73        640: 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      4.25G      0.652     0.7287     0.8767         72        640: 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      4.26G     0.6517     0.7568     0.8973         75        640: 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      4.28G      0.648     0.7326     0.8471         72        640: 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      4.24G     0.6377     0.7674     0.8566         69        640: 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1ss
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      4.24G     0.6359     0.7504     0.8661         88        640: 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.20it/s 5.1s
#                    all          7         49      0.906      0.668      0.983       0.86
#
# 50 epochs completed in 0.027 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 5.5MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 5.5MB
#
# Validating runs/detect/train3/weights/best.pt...
# Ultralytics 8.3.189 🚀 Python-3.13.5 torch-2.8.0 MPS (Apple M4 Pro)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all          7         49      0.905      0.667      0.983       0.86
#                   bomb          7         15          1      0.624      0.976      0.828
#  disabled_watering_can          1          1      0.837          1      0.995      0.895
#                droplet          7         27          1     0.0442      0.966      0.797
#           watering_can          6          6      0.784          1      0.995      0.918
# Speed: 0.7ms preprocess, 68.5ms inference, 0.0ms loss, 41.5ms postprocess per image
# Results saved to runs/detect/train3
